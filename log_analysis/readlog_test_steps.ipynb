# %%
import pandas as pd
import re
import numpy as np

# %%
import re
#df = pd.read_csv(r'C:\Users\sreddy\OneDrive - MerckGroup\New folder\process_logs\2020_02_29-application_1580556634479_40389.csv')
infile=r'C:\Users\sreddy\OneDrive - MerckGroup\New folder\process_logs\1application_1568810042014_190734.csv'
outfile=r'C:\Users\sreddy\OneDrive - MerckGroup\New folder\process_logs\2application_1568810042014_190734_processed.csv'
with open(infile,'r') as read_f:
    lines=read_f.readlines()
with open(outfile,'w') as write_f:
    for line in lines:
        if line.split("|")[0] in ["ERROR","INFO","WARN","FATAL","DEBUG","TRACE"]:
            #SUID Replace
            lowerLine=line.lower()
            modified=re.sub(r's[0-9._-]+',' ', lowerLine)
            #Unix Path replace
            modified=re.sub(r'(/[a-zA-Z0-9\.\-\_/]*/*[\s]?)',' ', modified)        
            #Network IP replace
            modified=re.sub(r'(?<![0-9])(?:(?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2}))(?![0-9])','', modified)        
            #Host name replace
            modified=re.sub(r'(?:[0-9A-Za-z]{0,62})(?:\.)',' ', modified)
            #remove Numbers 
            modified=re.sub(r'\d+',' ', modified)
            #Remove special charectors
            modified = re.sub('[@#$%^&*;\-_//>\"=\?\>:\\t]+',' ', modified)
            modified = re.sub(',,$','', modified)
            write_f.write(modified)

# %%
with open(r'C:\Users\sreddy\OneDrive - MerckGroup\New folder\process_logs\application_1576136188037_14697_junkless.csv','r') as read_f:
    lines=read_f.readlines()
    for line in lines:
        #SUID Replace
        modified=re.sub(r's[0-9._-]+','username', line)
        #Unix Path replace
        modified=re.sub(r'(/[a-zA-Z0-9\.\-\_/]*/*[\s]?)','unixpath', modified)        
        #Network IP replace
        modified=re.sub(r'(?<![0-9])(?:(?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2}))(?![0-9])','networkip', modified)        
        #Host name replace
        modified=re.sub(r'\d+','0', modified)
        modified=re.sub(r'\s+',' ', modified)
        print(modified)

# %% [markdown]
# ## Try step-by-step

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# #### Convert to small case and replace SUID

# %%
infile=r'C:\Users\sreddy\OneDrive - MerckGroup\New folder\process_logs\1application_1568810042014_190734.csv'
outfile=r'C:\Users\sreddy\OneDrive - MerckGroup\New folder\process_logs\2application_1568810042014_190734_processed.csv'
with open(infile,'r') as read_f:
    lines=read_f.readlines()
with open(outfile,'w') as write_f:
    for line in lines:
        if line.split("|")[0] in ["ERROR","INFO","WARN","FATAL","DEBUG","TRACE"]:
            #SUID Replace
            lowerLine=line.lower()
            #print(type(lowerLine))
            #Alias class replace
            modified=re.sub(r'([\w.-]+)@([\w.-]+)',':TOK_ALIAS', lowerLine)
            print(type(modified))
            #print(modified7)  
            modified=re.sub(r' s[0-9._-]+','TOK_SUID', modified)
            #Unix Path replace
            modified=re.sub(r'(/[a-zA-Z0-9\.\-\_/]*/*[\s]?)',' TOK_UNIXPATH ', modified)   
            #print(modified2)
            #Unix Path replace
            modified=re.sub(r"[a-z]+.(spark|tcp|https|http:hdfs:)://[a-z]*@+[a-zA-Z0-9\.]*.*",' TOK_URI ', modified)   
            #print(modified3)
            #Network IP replace
            modified=re.sub(r'(?<![0-9])(?:(?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2})[.](?:25[0-5]|2[0-4][0-9]|[0-1]?[0-9]{1,2}))(?![0-9])','TOK_IP_ADDRESS', modified)        
            #print(modified4)            
            #Host name replace
            #modified=re.sub(r'(?:[A-Za-z0-9\.]{2,63})(?:\.)','TOK_HOSTNAME', modified)
            #print(modified5)            
            #PORT replace
            modified=re.sub(r':\d*\d*\d*\d*\d',':TOK_PORT', modified)
            #print(modified6)
            #All Numbers to o 
            modified=re.sub(r'\d+','0', modified)
            #print(modified8)
            #modified = re.sub('[@#$%^&*;\-_//>\"=\?\>:\\t]+',' ', modified)
            #Remove trailing deliiter
            modified = re.sub('[|]+$','', modified)
            #print(modified)
            write_f.write(modified)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# #### Read UserNames

# %%
a='INFO|ExecutorRunnable: Starting Executor Container||'
re.sub('[|]+$','', a)
# Out:
# 'INFO|ExecutorRunnable: Starting Executor Container'

# %%
class modifiedd:
    def __init__(self, message):
        self.message = message

>>> my_car = modifiedd()
